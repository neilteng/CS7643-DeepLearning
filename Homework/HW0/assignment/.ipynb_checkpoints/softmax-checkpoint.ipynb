# %% [markdown]
# # Softmax Classifier

# %% [markdown]
# This exercise guides you through the process of classifying images using a Softmax classifier. As part of this you will:
#
# - Implement a fully vectorized loss function for the Softmax classifier
# - Calculate the analytical gradient using vectorized code
# - Tune hyperparameters on a validation set
# - Optimize the loss function with Stochastic Gradient Descent (SGD)
# - Visualize the learned weights

# %%
# start-up code! 
import random
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
from load_cifar10_tvt import load_cifar10_train_val
X_train, y_train, X_val, y_val, X_test, y_test = load_cifar10_train_val()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Val data shape: ', X_val.shape
print 'Val labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
# Out:
# Train, validation and testing sets have been created as
#  X_i and y_i where i=train,val,test
# Train data shape:  (3073, 49000)
# Train labels shape:  (49000,)
# Val data shape:  (3073, 1000)
# Val labels shape:  (1000,)
# Test data shape:  (3073, 1000)
# Test labels shape:  (1000,)

# %% [markdown]
# Code for this section is to be written in `f17cs7643/classifiers/softmax.py`

# %%
# Now, implement the vectorized version in softmax_loss_vectorized.

import time
from f17cs7643.classifiers.softmax import softmax_loss_vectorized

W = np.random.randn(10, 3073) * 0.0001

tic = time.time()
loss, grad = softmax_loss_vectorized(W, X_train, y_train, 0.00001)
toc = time.time()
print 'vectorized loss: %e computed in %fs' % (loss, toc - tic)

# As a rough sanity check, our loss should be something close to -log(0.1).
print 'loss: %f' % loss
print 'sanity check: %f' % (-np.log(0.1))

# gradient check. 
from f17cs7643.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_vectorized(w, X_train, y_train, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# vectorized loss: 2.322310e+00 computed in 0.180181s
# loss: 2.322310
# sanity check: 2.302585
# numerical: 0.955236 analytic: 0.955236, relative error: 2.229340e-08
# numerical: -0.577465 analytic: -0.577465, relative error: 1.761464e-08
# numerical: 2.441826 analytic: 2.441826, relative error: 7.785451e-09
# numerical: 1.528670 analytic: 1.528670, relative error: 1.818488e-08
# numerical: 1.527956 analytic: 1.527956, relative error: 5.390459e-08
# numerical: 0.893524 analytic: 0.893524, relative error: 4.863353e-08
# numerical: 2.343830 analytic: 2.343830, relative error: 1.919827e-08
# numerical: 3.027109 analytic: 3.027108, relative error: 8.550330e-09
# numerical: -1.237833 analytic: -1.237833, relative error: 2.467455e-08
# numerical: 0.886702 analytic: 0.886702, relative error: 1.826219e-08

# %%
# Now that efficient implementations to calculate loss function and gradient of the softmax are ready,
# use it to train the classifier on the cifar-10 data
from f17cs7643.classifiers import Softmax
classifier = Softmax()
loss_hist, acc_hist = classifier.train(X_train, y_train, learning_rate=1e-3, reg=1e-4, num_iters=10000,batch_size=50, verbose=True)
# Plot loss vs. iterations
# plt.plot(loss_hist)
# plt.xlabel('Iteration number')
# plt.ylabel('Loss value')

fig, ax1 = plt.subplots()
ax1.plot(loss_hist, 'b-')
ax1.set_xlabel('Iteration number')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('Loss value', color='b')
# ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
acc_hist = np.asarray(acc_hist)
idx = np.arange(1, len(acc_hist), 50)
ax2.plot(idx,acc_hist[::50], 'r')
ax2.set_ylabel('Accuracy value', color='r')
# ax2.tick_params('y', colors='r')

fig.tight_layout()
plt.show()
# Out:
# float64
# iteration 0 / 10000: loss 6.197335, acc 0.100000
# iteration 100 / 10000: loss 538.872718, acc 0.240000
# iteration 200 / 10000: loss 399.178501, acc 0.280000
# iteration 5300 / 10000: loss 48.063165, acc 0.400000
# iteration 5400 / 10000: loss 62.918253, acc 0.320000
# iteration 5500 / 10000: loss 63.740594, acc 0.260000
# iteration 5600 / 10000: loss 36.842713, acc 0.460000
# iteration 5700 / 10000: loss 26.367259, acc 0.500000
# iteration 5800 / 10000: loss 67.841495, acc 0.260000
# iteration 5900 / 10000: loss 53.458827, acc 0.400000
# iteration 6000 / 10000: loss 55.901933, acc 0.300000
# iteration 6100 / 10000: loss 36.924274, acc 0.460000
# iteration 6200 / 10000: loss 58.838071, acc 0.280000
# iteration 6300 / 10000: loss 55.715965, acc 0.380000
# iteration 6400 / 10000: loss 36.119383, acc 0.420000
# iteration 6500 / 10000: loss 44.777831, acc 0.380000
# iteration 6600 / 10000: loss 41.125818, acc 0.300000
# iteration 6700 / 10000: loss 55.257428, acc 0.420000
# iteration 6800 / 10000: loss 48.957162, acc 0.440000
# iteration 6900 / 10000: loss 32.352109, acc 0.460000
# iteration 7000 / 10000: loss 46.601416, acc 0.400000
# iteration 7100 / 10000: loss 28.527076, acc 0.400000
# iteration 7200 / 10000: loss 33.712062, acc 0.460000
# iteration 7300 / 10000: loss 49.669679, acc 0.380000
# iteration 7400 / 10000: loss 44.358843, acc 0.360000
# iteration 7500 / 10000: loss 42.033417, acc 0.280000
# iteration 7600 / 10000: loss 42.235446, acc 0.280000
# iteration 7700 / 10000: loss 50.247995, acc 0.220000
# iteration 7800 / 10000: loss 22.618669, acc 0.460000
# iteration 7900 / 10000: loss 50.002984, acc 0.360000
# iteration 8000 / 10000: loss 53.755751, acc 0.340000
# iteration 8100 / 10000: loss 47.534841, acc 0.380000
# iteration 8200 / 10000: loss 53.071667, acc 0.380000
# iteration 8300 / 10000: loss 46.869808, acc 0.360000
# iteration 8400 / 10000: loss 48.074352, acc 0.480000
# iteration 8500 / 10000: loss 44.892312, acc 0.440000
# iteration 8600 / 10000: loss 38.434164, acc 0.460000
# iteration 8700 / 10000: loss 30.614380, acc 0.460000
# iteration 8800 / 10000: loss 49.728608, acc 0.360000
# iteration 8900 / 10000: loss 50.490286, acc 0.300000
# iteration 9000 / 10000: loss 39.996886, acc 0.420000
# iteration 9100 / 10000: loss 36.512465, acc 0.520000
# iteration 9200 / 10000: loss 45.990793, acc 0.280000
# iteration 9300 / 10000: loss 56.924974, acc 0.280000
# iteration 9400 / 10000: loss 31.295975, acc 0.540000
# iteration 9500 / 10000: loss 34.865101, acc 0.340000
# iteration 9600 / 10000: loss 41.585285, acc 0.440000
# iteration 9700 / 10000: loss 52.818654, acc 0.320000
# iteration 9800 / 10000: loss 38.096944, acc 0.440000
# iteration 9900 / 10000: loss 54.759003, acc 0.320000

# %%
# Evaluate on test set
y_test_pred = classifier.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print 'softmax on raw pixels final test set accuracy: %f' % (test_accuracy, )
# Out:
# softmax on raw pixels final test set accuracy: 0.332000

# %%
# Visualize the learned weights for each class
w = classifier.W[:,:-1] # strip out the bias
print classifier.W.shape
w = w.reshape(10, 32, 32, 3)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in xrange(10):
  plt.subplot(2, 5, i + 1)
  
  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])
# Out:
# (10, 3073)
